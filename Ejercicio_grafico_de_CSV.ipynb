# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeUgalde/Sistemas_Expertos_Ejercicios/blob/main/Ejercicio_grafico_de_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ventas_mensuales.csv')

# %% [markdown]
# Enumerar info de archivo

# %%
df.head(5)
# Out:
#        Mes  Ventas
# 0    Enero   10000
# 1  Febrero   12000
# 2    Marzo   15000
# 3    Abril   13000
# 4     Mayo   14000

# %% [markdown]
# Detalle tipo data

# %%
df.describe()
# Out:
#              Ventas
# count     12.000000
# mean   16416.666667
# std     3752.776750
# min    10000.000000
# 25%    13750.000000
# 50%    16500.000000
# 75%    19250.000000
# max    22000.000000

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Mes'],df['Ventas'],marker='o',color='r',linestyle='-',linewidth=2)
plt.title('Ventas Mensuales')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
